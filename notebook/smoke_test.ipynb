# %%
import pandas as pd
df = pd.read_csv("../Data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (4, 3)
#      name  score  passed
# 0    Luma     85    True
# 1  Nasser     72    True
# 2    Majd     60   False
# 3   Diala     91    True
#            score
# count   4.000000
# mean   77.000000
# std    13.832329
# min    60.000000
# 25%    69.000000
# 50%    78.500000
# 75%    86.500000
# max    91.000000
